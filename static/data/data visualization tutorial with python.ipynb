# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
dates = ["2018-01-01", "2018-01-02", "2018-01-03"]
power = [0.0, 0.103, 1.839]
plt.plot(dates,power)
plt.show()

# %%
sample_data = pd.read_csv('2018TimeSeries2.csv')

# %%
sample_data
# Out:
#          Timestamp  Power
# 0    1/1/2018 0:00  0.000
# 1    1/1/2018 0:15  0.000
# 2    1/1/2018 0:30  0.000
# 3    1/1/2018 0:45  0.000
# 4    1/1/2018 1:00  0.000
# 5    1/1/2018 1:15  0.000
# 6    1/1/2018 1:30  0.000
# 7    1/1/2018 1:45  0.000
# 8    1/1/2018 2:00  1.562
# 9    1/1/2018 2:15  0.514
# 10   1/1/2018 2:30  0.000
# 11   1/1/2018 2:45  0.000
# 12   1/1/2018 3:00  0.000
# 13   1/1/2018 3:15  0.000
# 14   1/1/2018 3:30  0.000
# 15   1/1/2018 3:45  0.000
# 16   1/1/2018 4:00  0.000
# 17   1/1/2018 4:15  0.000
# 18   1/1/2018 4:30  0.000
# 19   1/1/2018 4:45  0.000
# 20   1/1/2018 5:00  0.000
# 21   1/1/2018 5:15  0.000
# 22   1/1/2018 5:30  0.000
# 23   1/1/2018 5:45  0.000
# 24   1/1/2018 6:00  0.000
# 25   1/1/2018 6:15  0.000
# 26   1/1/2018 6:30  0.001
# 27   1/1/2018 6:45  0.000
# 28   1/1/2018 7:00  0.000
# 29   1/1/2018 7:15  0.000
# ..             ...    ...
# 66  1/1/2018 16:30  0.000
# 67  1/1/2018 16:45  0.000
# 68  1/1/2018 17:00  0.000
# ...

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.Timestamp.iloc[1] # index value of the series in Timestamp col
# Out:
# '1/1/2018 0:15'

# %%
plt.plot(sample_data.Timestamp, sample_data.Power)
plt.show()

# %%
data = pd.read_csv('2018TimeSeries.csv')

# %%
data
# Out:
#               Timestamp  Power
# 0         1/1/2018 0:00  0.000
# 1         1/1/2018 0:15  0.000
# 2         1/1/2018 0:30  0.000
# 3         1/1/2018 0:45  0.000
# 4         1/1/2018 1:00  0.000
# 5         1/1/2018 1:15  0.000
# 6         1/1/2018 1:30  0.000
# 7         1/1/2018 1:45  0.000
# 8         1/1/2018 2:00  1.562
# 9         1/1/2018 2:15  0.514
# 10        1/1/2018 2:30  0.000
# 11        1/1/2018 2:45  0.000
# 12        1/1/2018 3:00  0.000
# 13        1/1/2018 3:15  0.000
# 14        1/1/2018 3:30  0.000
# 15        1/1/2018 3:45  0.000
# 16        1/1/2018 4:00  0.000
# 17        1/1/2018 4:15  0.000
# 18        1/1/2018 4:30  0.000
# 19        1/1/2018 4:45  0.000
# 20        1/1/2018 5:00  0.000
# 21        1/1/2018 5:15  0.000
# 22        1/1/2018 5:30  0.000
# 23        1/1/2018 5:45  0.000
# 24        1/1/2018 6:00  0.000
# 25        1/1/2018 6:15  0.000
# 26        1/1/2018 6:30  0.001
# 27        1/1/2018 6:45  0.000
# 28        1/1/2018 7:00  0.000
# ...

# %%
# Compare the values of certain dates
day1 = data[data.Timestamp == '1/1/2018 0:00']
day1
# Out:
#        Timestamp  Power
# 0  1/1/2018 0:00    0.0
